# %% [markdown]
# **What is an NLTK preprocessing pipeline?**
#
#
# Preprocessing in Natural Language Processing (NLP) is a means to get text data ready for further processing or analysis. Most of the time, preprocessing is a mix of cleaning and normalising techniques that make the text easier to use for the task at hand.
#
# A useful library for processing text in Python is the Natural Language Toolkit (NLTK). This guide will go into 14 of the most commonly used pre-processing steps and provide code examples so you can start using the techniques immediately.
#
# After this we will build an NLP preprocessing pipeline completely in NLTK so that you can see how these techniques can be used together, to create a whole system.
#
# Note that every application is different and would require a different pre-processing pipeline. The key here is to understand the different building blocks so that you can put them together to build your own pipeline.
#
# **Why use NLTK for preprocessing?**
#
# The Natural Language Toolkit (NLTK) is a popular Python library for working with human language data (text). There are plenty of good reasons to use NLTK.
#
# **Ease of use:** NLTK provides a simple and intuitive interface for performing common NLP tasks such as tokenization, stemming, and part-of-speech tagging.
#
# **Large collection of data and resources:** NLTK includes a wide range of corpora (large collections of text data) and resources for working with them, such as lexicons, grammars, and corpora annotated with linguistic information.
#
# **Support for various languages:** NLTK supports several languages and provides tools for working with them, including tokenizers, stemmers, and other language-specific resources e.g. Arabic.
#
# **Active development and community:** NLTK is an actively developed library with a large and supportive community of users and contributors.
#
# **Compatibility with other libraries:** NLTK is compatible with other popular Python libraries for data manipulation and machine learning, such as NumPy and scikit-learn, making it easy to incorporate into larger projects.
#
# **Top 14 NLTK preprocessing steps**
#
# It’s useful to dig into the different components that can be used for preprocessing first. Once we understand these, we can build an entire pipeline. Some common NLP preprocessing steps include:
#
# **1. Tokenization**
#
# Splitting the text into individual words or subwords (tokens).
#
# Here is how to implement tokenization in NLTK:

# %%
# !pip install nltk

# %%
import nltk

# %% [markdown]
# NLTK requires specific datasets and models (in this case, the Punkt tokenizer models for sentence tokenization) to process text, which are not included with the initial installation of NLTK. This modular approach allows users to download only the resources they need for their specific task, optimizing resource usage and installation time.
#
# The Punkt tokenizer is a pre-trained unsupervised machine learning model that divides a text into a list of sentence tokens. It is particularly adept at handling abbreviations, collocations, and complex sentence structures, making it a valuable tool for text preprocessing in natural language processing (NLP) tasks.

# %%
# Download the punkt tokenizer models
nltk.download('punkt')

# Now you can proceed with your text tokenization
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language."

# Tokenize the text
tokens = nltk.word_tokenize(text)

print("Tokens:", tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Tokens: ['Natural', 'language', 'processing', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'human', '(', 'natural', ')', 'language', '.']

# %%
for i in tokens:
  print(i)
# Out:
# Natural
# language
# processing
# is
# a
# field
# of
# artificial
# intelligence
# that
# deals
# with
# the
# interaction
# between
# computers
# and
# human
# (
# natural
# )
# language
# .

# %% [markdown]
# The nltk.word_tokenize() function uses the Punkt tokenization algorithm, which is a widely used method for tokenizing text in multiple languages. You can also use other tokenization methods, such as splitting the text on whitespace or punctuation, but these may not be as reliable for handling complex text structures and languages.
#
# **2. Lowercasing**
#
#
# Converting all text to lowercase to make it case-insensitive. To lowercase the tokens in a list using NLTK, you can simply use the built-in lower() method for strings:

# %%
#print(type(tokens))
for i in tokens:
  print(i.lower())
# Out:
# natural
# language
# processing
# is
# a
# field
# of
# artificial
# intelligence
# that
# deals
# with
# the
# interaction
# between
# computers
# and
# human
# (
# natural
# )
# language
# .

# %%
lowercased_tokens = [token.lower() for token in tokens]

print("Lowercased tokens:", lowercased_tokens)
# Out:
# Lowercased tokens: ['natural', 'language', 'processing', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'human', '(', 'natural', ')', 'language', '.']

# %% [markdown]
# **3. Remove punctuation**
#
# Removing punctuation marks simplifies the text and make it easier to process.
#
# To remove punctuation from a list of tokens using NLTK, you can use the string module to check if each token is a punctuation character. Here is an example of how to do this:

# %%
import string
print(lowercased_tokens)

# Create an empty list to hold the filtered tokens
filtered_tokens = []

# Iterate over each token in the original list of tokens
for token in lowercased_tokens:
    # Check if the token is NOT in the string.punctuation
    if token not in string.punctuation:
        # If the token is not a punctuation mark, add it to the filtered_tokens list
        filtered_tokens.append(token)

# The filtered_tokens list now contains tokens without any punctuation
print("Filtered Tokens:", filtered_tokens)
# Out:
# ['natural', 'language', 'processing', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'human', '(', 'natural', ')', 'language', '.']
# Filtered Tokens: ['natural', 'language', 'processing', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'human', 'natural', 'language']

# %% [markdown]
# **4. Remove stop words**
#
#
# Removing common words that do not add significant meaning to the text, such as “a,” “an,” and “the.”
#
# To remove common stop words from a list of tokens using NLTK, you can use the nltk.corpus.stopwords.words() function to get a list of stopwords in a specific language and filter the tokens using this list. Here is an example of how to do this:

# %%
nltk.download('stopwords')
# get list of stopwords in English
stopwords = nltk.corpus.stopwords.words("english")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# Create an empty list to hold the filtered tokens
filtered_tokens_stop = []

# Iterate over each token in the original list of tokens
for token in filtered_tokens:
    # Check if the token is NOT in the string.punctuation
    if token not in stopwords:
        # If the token is not a punctuation mark, add it to the filtered_tokens list
        filtered_tokens_stop.append(token)

# The filtered_tokens list now contains tokens without any punctuation
print("Filtered Tokens:", filtered_tokens_stop)
# Out:
# Filtered Tokens: ['natural', 'language', 'processing', 'field', 'artificial', 'intelligence', 'deals', 'interaction', 'computers', 'human', 'natural', 'language']

# %% [markdown]
# **5. Remove extra whitespace**
#
#
# White space could be spaces, tabs and newlines that don’t add value to further analysis.
#
# To remove extra white space from a string of text using NLTK you can use the string.strip() function to remove leading and trailing white space, and the string.replace() function to replace multiple consecutive white space characters with a single space. Here is an example of how to do this:

# %%
import nltk
import string

# input text with extra white space
text = "  Natural   language processing   is   a field   of artificial intelligence   that deals with the interaction between computers and human   (natural)   language.   "
print(len(text))
# remove leading and trailing white space
text = text.strip()

# replace multiple consecutive white space characters with a single space
text = " ".join(text.split())

print("Cleaned text:", text)
print(len(text))
# Out:
# 164
# Cleaned text: Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language.
# 145

# %% [markdown]
# **6. Remove URLs**
#
# To remove URLs from a string of text using NLTK, you can use a regular expression pattern to identify URLs and replace them with an empty string. Here is an example of how to do this:

# %%
import nltk
import re

# input text with URLs
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language. Check out this article for more information: https://en.wikipedia.org/wiki/Natural_language_processing"

# define a regular expression pattern to match URLs
pattern = r"(http|ftp|https)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?"

# replace URLs with an empty string
cleaned_text = re.sub(pattern, "", text)

print("Text without URLs:", cleaned_text)
# Out:
# Text without URLs: Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language. Check out this article for more information:

# %% [markdown]
# **7. Remove HTML code**
#
# To remove HTML code from a string of text using NLTK, you can use a regular expression pattern to identify HTML tags and replace them with an empty string. Here is an example of how to do this:

# %%
# input text with HTML code
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language. <b>This is an example of bold text.</b>"

# define a regular expression pattern to match HTML tags
pattern = r"<[^>]+>"

# replace HTML tags with an empty string
cleaned_text = re.sub(pattern, "", text)

print("Text without HTML code:", cleaned_text)
# Out:
# Text without HTML code: Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language. This is an example of bold text.

# %% [markdown]
# **8. Remove frequent words**
#
#
# To remove frequent words (also known as “high-frequency words”) from a list of tokens using NLTK, you can use the nltk.FreqDist() function to calculate the frequency of each word and filter out the most common ones. Here is an example of how to do this:

# %%
import nltk
nltk.download('punkt')  # Ensure you have the 'punkt' tokenizer models downloaded.
# input text
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language."
tokens = nltk.word_tokenize(text)
from collections import Counter

word_counts=Counter(tokens)
print("the msot common words are: ")
for i in word_counts.most_common():  #most_common arranges the word in descending order and prints the 11 most common words
  print(i)
# Out:
# the msot common words are:
# ('language', 2)
# ('Natural', 1)
# ('processing', 1)
# ('is', 1)
# ('a', 1)
# ('field', 1)
# ('of', 1)
# ('artificial', 1)
# ('intelligence', 1)
# ('that', 1)
# ('deals', 1)
# ('with', 1)
# ('the', 1)
# ('interaction', 1)
# ('between', 1)
# ('computers', 1)
# ('and', 1)
# ('human', 1)
# ('(', 1)
# ('natural', 1)
# (')', 1)
# ('.', 1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
nltk.download('punkt')  # Ensure you have the 'punkt' tokenizer models downloaded.

# Sample text
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language."

# Step 1: Tokenize the text
tokens = nltk.word_tokenize(text)

# Step 2: Calculate the frequency of each word
fdist = nltk.FreqDist(tokens)

# Step 3: Determine the number of words to remove (top 10% by frequency)
num_words_to_remove = len(fdist) // 10

# Identify the words to remove
words_to_remove = {word for word, frequency in fdist.most_common(num_words_to_remove)}

# Step 4: Filter out the most common words
filtered_tokens = [token for token in tokens if token not in words_to_remove]

print("Tokens without the top 10% frequent words:", filtered_tokens)
# Out:
# Tokens without the top 10% frequent words: ['processing', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'human', '(', 'natural', ')', '.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **9. Spelling correction**
#
# Correcting misspelt words is sometimes important so that the meaning of a sentence can be interpreted later in the processing.
#
# To perform spelling correction on a list of tokens using NLTK, you can use the nltk.corpus.words.words() function to get a list of English words and the nltk.edit_distance() function to calculate the edit distance between a word and the words in the list. Here is an example of how to do this:

# %%
import nltk

# Download the 'words' corpus
nltk.download('words')

# Now you can proceed with the rest of your code

# input text
text = "Natural langage processing is a field of artificial intelligece that deals with the interaction between computers and human (naturl) langage."

# tokenize the text
tokens = nltk.word_tokenize(text)

# get list of English words
words = nltk.corpus.words.words()

# correct spelling of each word
corrected_tokens = []
for token in tokens:
    # find the word with the lowest edit distance
    corrected_token = min(words, key=lambda x: nltk.edit_distance(x, token))
    corrected_tokens.append(corrected_token)

print("Corrected tokens:", corrected_tokens)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-02ca6493e756> in <cell line: 19>()
#      19 for token in tokens:
#      20     # find the word with the lowest edit distance
# ---> 21     corrected_token = min(words, key=lambda x: nltk.edit_distance(x, token))
#      22     corrected_tokens.append(corrected_token)
#      23
#
# <ipython-input-16-02ca6493e756> in <lambda>(x)
#      19 for token in tokens:
#      20     # find the word with the lowest edit distance
# ---> 21     corrected_token = min(words, key=lambda x: nltk.edit_distance(x, token))
#      22     corrected_tokens.append(corrected_token)
#      23
#
# /usr/local/lib/python3.10/dist-packages/nltk/metrics/distance.py in edit_distance(s1, s2, substitution_cost, transpositions)
# ...

# %% [markdown]
# To simplify the code for stemming tokens using the NLTK library and break it down into steps, we'll focus on the essential processes: tokenization, stemming, and printing the stemmed tokens.
#
# Step-by-Step Implementation:
#
# Tokenization: Break down the input text into individual words or tokens.
#
# Stemming: Apply stemming to each token to obtain its root form.
#
# Printing: Display the stemmed tokens.

# %% [markdown]
# **10. Stemming**
#
# Reducing words to their base form, such as converting “jumping” to “jump.”
#
# To perform stemming on a list of tokens using NLTK, you can use the nltk.stem.PorterStemmer() function to create a stemmer object and the stem() method to stem each token. Here is an example of how to do this:

# %%
import nltk

# Step 1: Tokenize the text
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language."
tokens = nltk.word_tokenize(text)

# Step 2: Create a stemmer object
stemmer = nltk.stem.PorterStemmer()

# Step 3: Stem each token
stemmed_tokens = []
for token in tokens:
    stemmed_token = stemmer.stem(token)
    stemmed_tokens.append(stemmed_token)

# Step 4: Print the stemmed tokens
print("Stemmed tokens:", stemmed_tokens)

# %% [markdown]
# The Porter stemmer is a widely used algorithm that removes common morphological affixes from words in order to obtain their base form or root. Other stemmers are also available in the nltk library, such as the Snowball stemmer, which supports multiple languages.

# %% [markdown]
# **11. Lemmatization**
#
# A more complicated and accurate method of reducing words to their base form than stemming.
#
# To perform lemmatization on a list of tokens using NLTK, you can use the nltk.stem.WordNetLemmatizer() function to create a lemmatizer object and the lemmatize() method to lemmatize each token. Here is an example of how to do this:

# %%
import nltk
nltk.download('punkt')  # For tokenization
nltk.download('wordnet')  # For lemmatization
# input text
text = "The geese are flying south for the winter."
# tokenize the text
tokens = nltk.word_tokenize(text)

# create lemmatizer object
lemmatizer = nltk.stem.WordNetLemmatizer()

# lemmatize each token
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

print("Lemmatized tokens:", lemmatized_tokens)

# %% [markdown]
# In this sentence, the words "geese" and "flying" stand out as candidates for lemmatization. "Geese" is the plural of "goose," and "flying" is the gerund or present participle form of the verb "fly." When we apply lemmatization to these words, we aim to find their base or lemma forms, which would be "goose" and "fly," respectively.
#
# After applying lemmatization to the entire sentence, the result might look something like this:
#
# Lemmatized Sentence:
# "The goose are fly south for the winter."
#
# In practice, lemmatization algorithms might not change all words, especially if the base form of the word does not differ from its variant in the original sentence or if the word's part-of-speech in the sentence does not necessitate any modification. However, for demonstrative purposes, this example focuses on the words "geese" and "flying" to show how they can be converted to their lemmas.
#
# This process is particularly useful in various natural language processing (NLP) applications where understanding the base form of words can significantly enhance the analysis. For instance, when performing text classification, information retrieval, or sentiment analysis, it's beneficial to consider the base forms of words to ensure that the algorithm recognizes different variants of a word as the same entity, thereby improving the accuracy and efficiency of computational analyses.
#
# The WordNet lemmatizer uses the WordNet database of English words to lemmatize the tokens, taking into account the part of speech and the context in which the word is used. You can specify the part of speech of the token using the pos argument of the lemmatize() method (e.g., "n" for nouns, "v" for verbs, etc.).
#
#
# **12. Part-of-speech tagging**
#
#
# Identifying the part of speech of each word in the text, such as noun, verb, or adjective.
#
# To perform part of speech (POS) tagging on a list of tokens using NLTK, you can use the nltk.pos_tag() function to tag the tokens with their corresponding POS tags. Here is an example of how to do this:

# %%
import nltk

# Download necessary NLTK data
nltk.download('punkt')  # For tokenizing text into words
nltk.download('averaged_perceptron_tagger')  # For POS tagging

# Input text
text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language."

# Tokenize the text
tokens = nltk.word_tokenize(text)

# Tag the tokens with their POS tags
tagged_tokens = nltk.pos_tag(tokens)

print("Tagged tokens:", tagged_tokens)

# %%
nltk.download('tagsets')

nltk.help.upenn_tagset()

# %%
textfile=open("//content/isro.txt","r")

# %%
textdata=textfile.read()

# %%
print(textdata)
# Out:
# The Indian Space Research Organisation (ISRO[3] /'?sro?/)[a] is the national space agency of India. It operates as the primary research and development arm of the Department of Space (DoS), which is directly overseen by the Prime Minister of India while the Chairman of ISRO also acts as the executive of DoS. ISRO is primarily responsible for performing tasks related to space-based operations, space exploration, international space cooperation and the development of related technologies.[4] ISRO is one of the six government space agencies in the world that possesses full launch capabilities, can deploy cryogenic engines, can launch extraterrestrial missions and operate a large fleet of artificial satellites.[5][6][b] ISRO is one of the four government space agencies to have soft landing (uncrewed) capabilities.[7][c]
#
# ...

# %%
# Download the punkt tokenizer models
nltk.download('punkt')

# Now you can proceed with your text tokenization
#text = "Natural language processing is a field of artificial intelligence that deals with the interaction between computers and human (natural) language."

# Tokenize the text
tokens = nltk.word_tokenize(textdata)

print("Tokens:", tokens)
# Out:
# Tokens: ['The', 'Indian', 'Space', 'Research', 'Organisation', '(', 'ISRO', '[', '3', ']', '/', "'", '?', 'sro', '?', '/', ')', '[', 'a', ']', 'is', 'the', 'national', 'space', 'agency', 'of', 'India', '.', 'It', 'operates', 'as', 'the', 'primary', 'research', 'and', 'development', 'arm', 'of', 'the', 'Department', 'of', 'Space', '(', 'DoS', ')', ',', 'which', 'is', 'directly', 'overseen', 'by', 'the', 'Prime', 'Minister', 'of', 'India', 'while', 'the', 'Chairman', 'of', 'ISRO', 'also', 'acts', 'as', 'the', 'executive', 'of', 'DoS', '.', 'ISRO', 'is', 'primarily', 'responsible', 'for', 'performing', 'tasks', 'related', 'to', 'space-based', 'operations', ',', 'space', 'exploration', ',', 'international', 'space', 'cooperation', 'and', 'the', 'development', 'of', 'related', 'technologies', '.', '[', '4', ']', 'ISRO', 'is', 'one', 'of', 'the', 'six', 'government', 'space', 'agencies', 'in', 'the', 'world', 'that', 'possesses', 'full', 'launch', 'capabilities', ',', 'can', 'deploy', 'cry
# ...

# %%
import string
print(lowercased_tokens)

# Create an empty list to hold the filtered tokens
filtered_tokens = []

# Iterate over each token in the original list of tokens
for token in lowercased_tokens:
    # Check if the token is NOT in the string.punctuation
    if token not in string.punctuation:
        # If the token is not a punctuation mark, add it to the filtered_tokens list
        filtered_tokens.append(tokens)

# The filtered_tokens list now contains tokens without any punctuation
print("Filtered Tokens:", filtered_tokens)
# Out:
# ['the', 'indian', 'space', 'research', 'organisation', '(', 'isro', '[', '3', ']', '/', "'", '?', 'sro', '?', '/', ')', '[', 'a', ']', 'is', 'the', 'national', 'space', 'agency', 'of', 'india', '.', 'it', 'operates', 'as', 'the', 'primary', 'research', 'and', 'development', 'arm', 'of', 'the', 'department', 'of', 'space', '(', 'dos', ')', ',', 'which', 'is', 'directly', 'overseen', 'by', 'the', 'prime', 'minister', 'of', 'india', 'while', 'the', 'chairman', 'of', 'isro', 'also', 'acts', 'as', 'the', 'executive', 'of', 'dos', '.', 'isro', 'is', 'primarily', 'responsible', 'for', 'performing', 'tasks', 'related', 'to', 'space-based', 'operations', ',', 'space', 'exploration', ',', 'international', 'space', 'cooperation', 'and', 'the', 'development', 'of', 'related', 'technologies', '.', '[', '4', ']', 'isro', 'is', 'one', 'of', 'the', 'six', 'government', 'space', 'agencies', 'in', 'the', 'world', 'that', 'possesses', 'full', 'launch', 'capabilities', ',', 'can', 'deploy', 'cryogenic',
# ...

# %%
lowercased_tokens = [token.lower() for token in tokens]

print("Lowercased tokens:", lowercased_tokens)
# Out:
# Lowercased tokens: ['the', 'indian', 'space', 'research', 'organisation', '(', 'isro', '[', '3', ']', '/', "'", '?', 'sro', '?', '/', ')', '[', 'a', ']', 'is', 'the', 'national', 'space', 'agency', 'of', 'india', '.', 'it', 'operates', 'as', 'the', 'primary', 'research', 'and', 'development', 'arm', 'of', 'the', 'department', 'of', 'space', '(', 'dos', ')', ',', 'which', 'is', 'directly', 'overseen', 'by', 'the', 'prime', 'minister', 'of', 'india', 'while', 'the', 'chairman', 'of', 'isro', 'also', 'acts', 'as', 'the', 'executive', 'of', 'dos', '.', 'isro', 'is', 'primarily', 'responsible', 'for', 'performing', 'tasks', 'related', 'to', 'space-based', 'operations', ',', 'space', 'exploration', ',', 'international', 'space', 'cooperation', 'and', 'the', 'development', 'of', 'related', 'technologies', '.', '[', '4', ']', 'isro', 'is', 'one', 'of', 'the', 'six', 'government', 'space', 'agencies', 'in', 'the', 'world', 'that', 'possesses', 'full', 'launch', 'capabilities', ',', 'can', 'de
# ...

# %%
import nltk
nltk.download('stopwords')

stopwords = nltk.corpus.stopwords.words("english")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# Create an empty list to hold the filtered tokens
filtered_tokens_stop = []

# Iterate over each token in the original list of tokens
for token in filtered_tokens:
    # Check if the token is NOT in the string.punctuation
    if token not in stopwords:
        # If the token is not a punctuation mark, add it to the filtered_tokens list
        filtered_tokens_stop.append(lowercased_tokens)

# The filtered_tokens list now contains tokens without any punctuation
print("Filtered Tokens:", filtered_tokens_stop)
# Out:
# Filtered Tokens: [['the', 'indian', 'space', 'research', 'organisation', '(', 'isro', '[', '3', ']', '/', "'", '?', 'sro', '?', '/', ')', '[', 'a', ']', 'is', 'the', 'national', 'space', 'agency', 'of', 'india', '.', 'it', 'operates', 'as', 'the', 'primary', 'research', 'and', 'development', 'arm', 'of', 'the', 'department', 'of', 'space', '(', 'dos', ')', ',', 'which', 'is', 'directly', 'overseen', 'by', 'the', 'prime', 'minister', 'of', 'india', 'while', 'the', 'chairman', 'of', 'isro', 'also', 'acts', 'as', 'the', 'executive', 'of', 'dos', '.', 'isro', 'is', 'primarily', 'responsible', 'for', 'performing', 'tasks', 'related', 'to', 'space-based', 'operations', ',', 'space', 'exploration', ',', 'international', 'space', 'cooperation', 'and', 'the', 'development', 'of', 'related', 'technologies', '.', '[', '4', ']', 'isro', 'is', 'one', 'of', 'the', 'six', 'government', 'space', 'agencies', 'in', 'the', 'world', 'that', 'possesses', 'full', 'launch', 'capabilities', ',', 'can', 'dep
# ...

# %%
import string
print(lowercased_tokens)

# Create an empty list to hold the filtered tokens
filtered_tokens = []

# Iterate over each token in the original list of tokens
for token in lowercased_tokens:
    # Check if the token is NOT in the string.punctuation
    if token not in string.punctuation:
        # If the token is not a punctuation mark, add it to the filtered_tokens list
        filtered_tokens.append(filtered_tokens_stop)

# The filtered_tokens list now contains tokens without any punctuation
print("Filtered Tokens:", filtered_tokens)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pip install wordcloud

# %%
filtered_text = ' '.join(filtered_tokens_stop)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Generate a word cloud image
wordcloud = WordCloud(width = 500, height = 500,
                background_color ='white',
                stopwords = None,
                min_font_size = 10).generate(filtered_text)

# Display the generated image:
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# Step 2: Create a stemmer object
stemmer = nltk.stem.PorterStemmer()

# Step 3: Stem each token
stemmed_tokens = []
for token in filtered_tokens_stop:
    stemmed_token = stemmer.stem(token)
    stemmed_tokens.append(stemmed_token)

# Step 4: Print the stemmed tokens
print("Stemmed tokens:", stemmed_tokens)
# Out:
# Stemmed tokens: ['natur', 'languag', 'process', 'field', 'artifici', 'intellig', 'deal', 'interact', 'comput', 'human', 'natur', 'languag']

# %%
import nltk
nltk.download('punkt')  # For tokenization
nltk.download('wordnet')  # For lemmatization
# input text
# tokenize the text


# create lemmatizer object
lemmatizer = nltk.stem.WordNetLemmatizer()

# lemmatize each token
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens_stop]

print("Lemmatized tokens:", lemmatized_tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Lemmatized tokens: ['natural', 'language', 'processing', 'field', 'artificial', 'intelligence', 'deal', 'interaction', 'computer', 'human', 'natural', 'language']

# %%
import nltk

# Download necessary NLTK data
nltk.download('punkt')  # For tokenizing text into words
nltk.download('averaged_perceptron_tagger')  # For POS tagging


# Tag the tokens with their POS tags
tagged_tokens = nltk.pos_tag(lemmatized_tokens)

print("Tagged tokens:", tagged_tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Tagged tokens: [('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('field', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('deal', 'NN'), ('interaction', 'NN'), ('computer', 'NN'), ('human', 'JJ'), ('natural', 'JJ'), ('language', 'NN')]

# %% [markdown]
# The POS tagger is an essential component in natural language processing (NLP) as it assigns each token in a text to a part-of-speech category based on its definition and context (e.g., noun, verb, adjective). This step is crucial for numerous NLP tasks, including parsing, named entity recognition, and even lemmatization, as knowing the part-of-speech of a word can significantly improve the accuracy of these processes.

# %% [markdown]
# **Feature extraction**
#
# 1. Bag of Words (BoW)
# The Bag of Words model converts text documents into numerical vectors where each document is represented by a vector indicating the frequency of each word from the entire dataset in the document.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Sample data
documents = "the cat is on the table", "the dog is in the house"

# Create the vectorizer and fit it to the documents
vectorizer = CountVectorizer()
bow_matrix = vectorizer.fit_transform(documents)

# Convert the matrix to an array and print it
print(bow_matrix.toarray())

# Print the feature names
print(vectorizer.get_feature_names_out())
# Out:
# [[1 0 0 0 1 1 1 2]
#  [0 1 1 1 1 0 0 2]]
# ['cat' 'dog' 'house' 'in' 'is' 'on' 'table' 'the']

# %% [markdown]
# **2. TF-IDF (Term Frequency-Inverse Document Frequency)**
# TF-IDF reflects how important a word is to a document in a collection or corpus. It increases proportionally to the number of times a word appears in the document but is offset by the frequency of the word in the corpus.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample data
documents = "the cat is on the table", "the dog is in the house"

# Create the vectorizer and fit it to the documents
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# Convert the matrix to an array and print it
print(tfidf_matrix.toarray())

# Print the feature names
print(tfidf_vectorizer.get_feature_names_out())
# Out:
# [[0.42519636 0.         0.         0.         0.30253071 0.42519636
#   0.42519636 0.60506143]
#  [0.         0.42519636 0.42519636 0.42519636 0.30253071 0.
#   0.         0.60506143]]
# ['cat' 'dog' 'house' 'in' 'is' 'on' 'table' 'the']

# %% [markdown]
# **3. Word Embeddings (Word2Vec and GloVe)**
# Word embeddings provide a dense representation of words and their relative meanings. They are based on the distributional hypothesis, which states that words that occur in the same contexts tend to have similar meanings.
#
# ** Word2Vec**: Expects a list of sentences, where each sentence is a list of words. This is because Word2Vec models learn from the context of words within sentences, so the input must be tokenized into sentences and then tokenized into words.
#
# Here's how you can preprocess a single block of text and then train a Word2Vec model with it using Python:
#
# Split the text into sentences. You can use libraries like nltk (Natural Language Toolkit) for more advanced sentence tokenization, which can accurately identify sentences based on punctuation and other cues.
#
# Tokenize each sentence into words. Again, this can be done using nltk or similar libraries to accurately tokenize words, taking care of punctuation and other potential issues.

# %%
from gensim.models import Word2Vec

# Sample data (tokenized sentences)
sentences = [["the", "cat", "is", "on", "the", "table"],
             ["the", "dog", "is", "in", "the", "house"]]

# Train a Word2Vec model
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# Access the vector for one word
print(model.wv['cat'])
# Out:
# [ 8.1681199e-03 -4.4430327e-03  8.9854337e-03  8.2536647e-03
#  -4.4352221e-03  3.0310510e-04  4.2744912e-03 -3.9263200e-03
#  -5.5599655e-03 -6.5123225e-03 -6.7073823e-04 -2.9592158e-04
#   4.4630850e-03 -2.4740540e-03 -1.7260908e-04  2.4618758e-03
#   4.8675989e-03 -3.0808449e-05 -6.3394094e-03 -9.2608072e-03
#   2.6657581e-05  6.6618943e-03  1.4660227e-03 -8.9665223e-03
#  -7.9386048e-03  6.5519023e-03 -3.7856805e-03  6.2549924e-03
#  -6.6810320e-03  8.4796622e-03 -6.5163244e-03  3.2880199e-03
#  -1.0569858e-03 -6.7875278e-03 -3.2875966e-03 -1.1614120e-03
#  -5.4709399e-03 -1.2113475e-03 -7.5633135e-03  2.6466595e-03
#   9.0701487e-03 -2.3772502e-03 -9.7651005e-04  3.5135616e-03
#   8.6650876e-03 -5.9218528e-03 -6.8875779e-03 -2.9329848e-03
#   9.1476962e-03  8.6626766e-04 -8.6784009e-03 -1.4469790e-03
#   9.4794659e-03 -7.5494875e-03 -5.3580985e-03  9.3165627e-03
#  -8.9737261e-03  3.8259076e-03  6.6544057e-04  6.6607012e-03
# ...

# %%
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')  # Download necessary datasets

# Single block of text
text = "The cat is on the table. The dog is in the house."

# Step 1: Split the text into sentences
sentences = sent_tokenize(text)

# Step 2: Tokenize each sentence into words
tokenized_sentences = [word_tokenize(sentence) for sentence in sentences]

# Now, you have the text in the format expected by Word2Vec
model = Word2Vec(tokenized_sentences, vector_size=100, window=5, min_count=1, workers=4)

# Access the vector for one word
print(model.wv['cat'])
# Out:
# [-0.00515624 -0.00666834 -0.00777684  0.00831073 -0.00198234 -0.00685496
#  -0.00415439  0.00514413 -0.00286914 -0.00374966  0.00162143 -0.00277629
#  -0.00158436  0.00107449 -0.00297794  0.00851928  0.00391094 -0.00995886
#   0.0062596  -0.00675425  0.00076943  0.00440423 -0.00510337 -0.00211067
#   0.00809548 -0.00424379 -0.00763626  0.00925791 -0.0021555  -0.00471943
#   0.0085708   0.00428334  0.00432484  0.00928451 -0.00845308  0.00525532
#   0.00203935  0.00418828  0.0016979   0.00446413  0.00448629  0.00610452
#  -0.0032021  -0.00457573 -0.00042652  0.00253373 -0.00326317  0.00605772
#   0.00415413  0.00776459  0.00256927  0.00811668 -0.00138721  0.00807793
#   0.00371702 -0.00804732 -0.00393361 -0.00247188  0.00489304 -0.00087216
#  -0.00283091  0.00783371  0.0093229  -0.00161493 -0.00515925 -0.00470176
#  -0.00484605 -0.00960283  0.00137202 -0.00422492  0.00252671  0.00561448
#  -0.00406591 -0.00959658  0.0015467  -0.00670012  0.00249517 -0.00378063
# ...

# %% [markdown]
# In this example, the sent_tokenize function splits the block of text into individual sentences, and word_tokenize breaks those sentences down into words. This format is then suitable for training a Word2Vec model. Note that you need to download the punkt dataset from NLTK the first time you run this code, as it's used by the tokenizer to determine the sentence boundaries. This approach ensures that the model learns from the context of words as they are used in natural language, which is crucial for producing meaningful word embeddings.
#
# other embedding  techniques:
# GloVe (Global Vectors for Word Representation)
# FastText
# ELMo (Embeddings from Language Models)
# BERT (Bidirectional Encoder Representations from Transformers)

# %%
pip install transformers

# %%
from transformers import BertTokenizer, BertModel
import torch

# Initialize the tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Sample text
text = "Here is the sentence I want embeddings for."

# Encode text
input_ids = tokenizer.encode(text, add_special_tokens=True)  # Add special tokens ([CLS], [SEP])
input_tensor = torch.tensor([input_ids])  # Convert to tensor

# Get embeddings
with torch.no_grad():
    outputs = model(input_tensor)
    last_hidden_states = outputs.last_hidden_state  # The last hidden-state is the first element of the output tuple

# Get the embeddings for the [CLS] token
cls_embeddings = last_hidden_states[:, 0, :].numpy()

print(cls_embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# [[-3.88212949e-02 -4.96123880e-02  6.81225210e-02 -2.98509479e-01
#   -2.98403591e-01 -3.08424830e-01  3.01204063e-02  2.02286124e-01
# ...
